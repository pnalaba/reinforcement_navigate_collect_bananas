# %%
from nnv import NNV

# Let's increase the size of the plot
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (200,10)


layers_list = [
    {"title":"input\n(37 nodes)\n(relu)", "units": 37, "color": "darkBlue"},
    {"title":"hidden 1\n(64 nodes)\n(relu)", "units": 64},
    {"title":"hidden 2\n(32 nodes)\n(relu)",  "units": 32},
    {"title":"hidden 3\n(16 nodes)\n(relu)",  "units": 16},
    {"title":"output\n(4 nodes)", "units": 4,"color": "darkBlue"},
]


NNV(layers_list, max_num_nodes_visible=8, node_radius=10, spacing_layer=60, font_size=24).render(save_to_file="my_network.pdf")
# Out:
# (<Figure size 14400x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7cfb839a58>)
